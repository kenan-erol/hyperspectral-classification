# %%
import os
from google.colab import drive
from google.colab import auth
from google.auth import default

drive.mount('/content/drive/', force_remount=True)
os.chdir('/content/drive/MyDrive/workspace/classification-tutorial')
# Out:
# Mounted at /content/drive/

# %%
from google.colab import runtime

# %%
# !mkdir bash/outputs
# !ls cifar_checkpoints/cifar_cnn_checkpoint_vgg.pth/

# %%
# sync with git
# !mkdir -p /root/.ssh

# !cp /content/drive/MyDrive/workspace/ssh_keys/* /root/.ssh/

# !ls -la /root/.ssh/
# !git config --global user.email "kenan.erol@yale.edu"
# !git config --global user.name "Kenan Erol"
# !ssh-keyscan github.com >> /root/.ssh/known_hosts
# !git status
# !git diff
# !git log
# !git fetch
# !git switch kenan-erol
# Out:
# total 20
# drwxr-xr-x 2 root root 4096 Feb  5 02:36 .
# drwx------ 1 root root 4096 Feb  5 02:36 ..
# -rw------- 1 root root 3381 Feb  5 02:36 id_rsa
# -rw------- 1 root root  743 Feb  5 02:36 id_rsa.pub
# # github.com:22 SSH-2.0-cb0cff27f
# # github.com:22 SSH-2.0-cb0cff27f
# # github.com:22 SSH-2.0-cb0cff27f
# # github.com:22 SSH-2.0-cb0cff27f
# # github.com:22 SSH-2.0-cb0cff27f
# Refresh index: 100% (26/26), done.
# On branch kenan-erol
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	outputs/
#
# nothing added to commit but untracked files present (use "git add" to track)
# Already on 'kenan-erol'

# %%
# !git config pull.rebase false
# !git pull origin kenan-erol
# Out:
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 9 (delta 7), reused 9 (delta 7), pack-reused 0 (from 0)
# Unpacking objects: 100% (9/9), 2.66 KiB | 25.00 KiB/s, done.
# From github.com:alexklwong/classification-tutorial
#  * branch            kenan-erol -> FETCH_HEAD
#    5d8924d..059d327  kenan-erol -> origin/kenan-erol
# Updating 5d8924d..059d327
# Fast-forward
#  src/classification_cnn.py       | 5 ++++-
#  src/classification_model.py     | 2 +-
#  src/net_utils.py                | 2 +-
#  src/networks.py                 | 4 ++--
#  src/run_classification_cnn.py   | 2 +-
#  src/train_classification_cnn.py | 4 ++--
#  6 files changed, 11 insertions(+), 8 deletions(-)

# %%
# !rm -r cifar_checkpoints/*
# !rm -r mnist_checkpoints/*
# Out:
# rm: cannot remove 'mnist_checkpoints/*': No such file or directory

# %% [markdown]
# ## Git Setup is now Complete
# # Following section is the NeuralNetwork part
# training takes 15 mins for mnist, 19 for cifar

# %%
# !source bash/train_classification_nn_mnist.sh
# Out:
# Epoch=1/40  Loss: 1.702
# Epoch=2/40  Loss: 0.688
# Epoch=3/40  Loss: 0.394
# Epoch=4/40  Loss: 0.284
# Epoch=5/40  Loss: 0.228
# Epoch=6/40  Loss: 0.193
# Epoch=7/40  Loss: 0.166
# Epoch=8/40  Loss: 0.150
# Epoch=9/40  Loss: 0.134
# Epoch=10/40  Loss: 0.122
# Epoch=11/40  Loss: 0.086
# Epoch=12/40  Loss: 0.074
# Epoch=13/40  Loss: 0.070
# Epoch=14/40  Loss: 0.067
# Epoch=15/40  Loss: 0.065
# Epoch=16/40  Loss: 0.063
# Epoch=17/40  Loss: 0.060
# Epoch=18/40  Loss: 0.057
# Epoch=19/40  Loss: 0.057
# Epoch=20/40  Loss: 0.055
# Epoch=21/40  Loss: 0.051
# Epoch=22/40  Loss: 0.051
# Epoch=23/40  Loss: 0.051
# Epoch=24/40  Loss: 0.050
# Epoch=25/40  Loss: 0.051
# Epoch=26/40  Loss: 0.051
# Epoch=27/40  Loss: 0.050
# Epoch=28/40  Loss: 0.051
# Epoch=29/40  Loss: 0.049
# Epoch=30/40  Loss: 0.049
# Epoch=31/40  Loss: 0.050
# Epoch=32/40  Loss: 0.050
# Epoch=33/40  Loss: 0.049
# Epoch=34/40  Loss: 0.048
# Epoch=35/40  Loss: 0.049
# Epoch=36/40  Loss: 0.049
# Epoch=37/40  Loss: 0.049
# ...

# %%
# !source bash/run_classification_nn_mnist.sh
# Out:
# /content/drive/MyDrive/workspace/classification-tutorial/src/run_classification_nn.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !source bash/train_classification_nn_cifar.sh
# Out:
# Files already downloaded and verified
# Epoch=1/50  Loss: 2.186
# Epoch=2/50  Loss: 1.960
# Epoch=3/50  Loss: 1.860
# Epoch=4/50  Loss: 1.783
# Epoch=5/50  Loss: 1.725
# Epoch=6/50  Loss: 1.674
# Epoch=7/50  Loss: 1.637
# Epoch=8/50  Loss: 1.594
# Epoch=9/50  Loss: 1.566
# Epoch=10/50  Loss: 1.536
# Epoch=11/50  Loss: 1.396
# Epoch=12/50  Loss: 1.375
# Epoch=13/50  Loss: 1.363
# Epoch=14/50  Loss: 1.352
# Epoch=15/50  Loss: 1.343
# Epoch=16/50  Loss: 1.332
# Epoch=17/50  Loss: 1.324
# Epoch=18/50  Loss: 1.316
# Epoch=19/50  Loss: 1.308
# Epoch=20/50  Loss: 1.299
# Epoch=21/50  Loss: 1.273
# Epoch=22/50  Loss: 1.270
# Epoch=23/50  Loss: 1.268
# Epoch=24/50  Loss: 1.262
# Epoch=25/50  Loss: 1.262
# Epoch=26/50  Loss: 1.263
# Epoch=27/50  Loss: 1.258
# Epoch=28/50  Loss: 1.259
# Epoch=29/50  Loss: 1.256
# Epoch=30/50  Loss: 1.257
# Epoch=31/50  Loss: 1.254
# Epoch=32/50  Loss: 1.254
# Epoch=33/50  Loss: 1.254
# Epoch=34/50  Loss: 1.252
# Epoch=35/50  Loss: 1.253
# ...

# %%
# !source bash/run_classification_nn_cifar.sh
# Out:
# Files already downloaded and verified
# ...

# %% [markdown]
# # Following section is the CNN part
#
# resnet:

# %%
# !rm -r cifar_checkpoints/*
# !rm -r mnist_checkpoints/*
# make sure to empty trash
# Out:
# rm: cannot remove 'mnist_checkpoints/*': No such file or directory

# %%
# !ls -al
# Out:
# total 69
# drwx------ 5 root root  4096 Feb  2 23:35 bash
# drwx------ 2 root root  4096 Feb  2 23:35 cifar_checkpoints
# -rw------- 1 root root 37421 Feb  2 23:35 classification-tutorial.ipynb
# drwx------ 2 root root  4096 Jan 30 09:47 data
# drwx------ 7 root root  4096 Feb  2 23:35 .git
# -rw------- 1 root root   145 Jan 30 08:46 .gitignore
# drwx------ 2 root root  4096 Jan 28 10:56 mnist_checkpoints
# drwx------ 2 root root  4096 Jan 28 15:35 outputs
# -rw------- 1 root root  2985 Feb  2 23:29 README.md
# drwx------ 3 root root  4096 Jan 30 09:47 src

# %%
# !source bash/train_classification_cnn_mnist_resnet.sh
# Out:
# 2025-02-02 23:40:16.746078: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738539616.765954    5526 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738539616.772131    5526 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-02 23:40:16.792300: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch=1/50  Loss: nan
# ...

# %%
# !source bash/run_classification_cnn_mnist_resnet.sh
# !rm -r mnist_checkpoints/*

# %%
# !ls mnist_checkpoints/

# %% [markdown]
# # This one left

# %%
# !source bash/train_classification_cnn_cifar_resnet.sh
# Out:
# 2025-02-05 06:18:36.009639: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738736316.030473   62384 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738736316.036750   62384 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-05 06:18:36.057592: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !source bash/run_classification_cnn_cifar_resnet.sh
# Out:
# 2025-02-05 09:45:52.406351: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738748752.427806  119940 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738748752.434428  119940 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-05 09:45:52.455705: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !rm -r cifar_checkpoints/cifar_cnn_checkpoint_resnet.pth
# !ls cifar_checkpoints/
# runtime.unassign() # to save gpu

# %% [markdown]
# vgg

# %%
# !source bash/train_classification_cnn_mnist_vgg.sh
# Out:
# 2025-02-02 19:51:45.759319: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738525905.780447   25484 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738525905.786954   25484 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-02 19:51:45.808557: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !source bash/run_classification_cnn_mnist_vgg.sh
# Out:
# 2025-02-02 21:06:18.250507: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738530378.271755   45646 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738530378.278131   45646 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-02 21:06:18.299626: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !rm -r mnist_checkpoints/mnist_cnn_checkpoint_vgg.pth
# !ls mnist_checkpoints/

# %%
# !source bash/train_classification_cnn_cifar_vgg.sh
# Out:
# 2025-02-02 21:06:36.240077: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738530396.274980   45752 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738530396.285668   45752 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-02 21:06:36.317436: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !source bash/run_classification_cnn_cifar_vgg.sh
# Out:
# 2025-02-02 22:36:23.770608: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1738535783.792571   69910 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1738535783.799250   69910 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-02 22:36:23.822068: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !rm -r cifar_checkpoints/cifar_cnn_checkpoint_vgg.pth
# !ls cifar_checkpoints/

# %%
runtime.unassign() # to save gpu
